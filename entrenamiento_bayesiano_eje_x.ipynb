# %% [markdown]
# <a href="https://colab.research.google.com/github/naldo14/tesis-/blob/main/entrenamiento_bayesiano_eje_x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## importo las librerias
import h5py
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
from tensorflow import keras
from tensorflow.keras.callbacks import LearningRateScheduler
tfd = tfp.distributions
tfpl = tfp.layers

# %%
## hago el mounting
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Proceso de carga de los datos

# %% [markdown]
# ### data sobre el eje *y*

# %%
#creo el h5py de las features
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/features_y"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'r') as hf:
    y_features = hf['features_y'][:]

# %%
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/y_targets"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'r') as hf:
    y_targets = hf['y_targets'][:]

# %%
y_targets.shape
# Out:
# (55,)

# %% [markdown]
# ### data sobre el eje *x*

# %%
#creo el h5py de las features
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/features_x"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'r') as hf:
   x_features = hf['features_x'][:]

# %%
path_features="/content/drive/MyDrive/tesis USB /Vibration, acoustic, temperature, and motor current dataset of rotating machine under varying operating conditions for fault diagnosis (korea)/x_targets"
hdf5_file_path = path_features
with h5py.File(hdf5_file_path, 'r') as hf:
    x_targets = hf['x_targets'][:]

# %%
## data sets but using y-axis measures
from sklearn.model_selection import train_test_split
# Assuming x is your dataset with shape (70, 14) and y is your labels
x_train, x_test, y_train, y_test = train_test_split(y_features, y_targets, test_size=0.3, random_state=42)

print("corrida usando el eje y")

# %%
## data sets but using x-axis measures
from sklearn.model_selection import train_test_split
# Assuming x is your dataset with shape (70, 14) and y is your labels
x_train, x_test, y_train, y_test = train_test_split(x_features, x_targets, test_size=0.3, random_state=42)
print("corrida usando el eje x")
# Out:
# corrida usando el eje x

# %%
del x_train, x_test, y_train, y_test

# %% [markdown]
# ### Creacion de la BNN

# %%
## def prior weight distribution N(1,0) and not trainable
# Define the prior weight distribution N(0, 1)
def prior(kernel_size, bias_size, dtype=None):
    n = kernel_size + bias_size
    prior_model = keras.Sequential(
        [
            tfp.layers.DistributionLambda(
                lambda t: tfp.distributions.MultivariateNormalDiag(
                    loc=tf.zeros(n), scale_diag=tf.ones(n)
                )
            )
        ]
    )
    return prior_model

# %%
# Define the posterior weight distribution Multivariate Gaussian distribution
def posterior(kernel_size, bias_size, dtype=None):
    n = kernel_size + bias_size
    posterior_model = keras.Sequential(
        [
            tfp.layers.VariableLayer(
                tfp.layers.MultivariateNormalTriL.params_size(n), dtype=dtype
            ),
            tfp.layers.MultivariateNormalTriL(n),
        ]
    )
    return posterior_model

# %%
# Define the BNN model
model = tf.keras.Sequential([
    tfpl.DenseVariational(
        input_shape=(14,),
        units=30,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        kl_weight=1/x_train.shape[0],  # KL Weight
        # kl_use_exact=True
    ),

       tfpl.DenseVariational(
        units=25,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),

    tfpl.DenseVariational(
        units=20,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),

    tfpl.DenseVariational(
        units=15,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),


      tfpl.DenseVariational(
        units=12,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),
    tfpl.DenseVariational(
        units=8,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),
    tfpl.DenseVariational(
        units=5,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='relu',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),
    tfpl.DenseVariational(
        units=1,
        make_prior_fn=prior,
        make_posterior_fn=posterior,
        activation='sigmoid',
        use_bias=True,
        kl_weight=1/x_train.shape[0]  # KL Weight
    ),
])

# %%
del model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_variational (DenseVa  (None, 30)                101925
#  riational)
#
#  dense_variational_1 (Dense  (None, 25)                301475
#  Variational)
#
#  dense_variational_2 (Dense  (None, 20)                135980
#  Variational)
#
#  dense_variational_3 (Dense  (None, 15)                50085
#  Variational)
#
#  dense_variational_4 (Dense  (None, 12)                18720
#  Variational)
#
#  dense_variational_5 (Dense  (None, 8)                 5564
#  Variational)
#
#  dense_variational_6 (Dense  (None, 5)                 1080
#  Variational)
#
#  dense_variational_7 (Dense  (None, 1)                 27
#  Variational)
#
# =================================================================
# Total params: 614856 (2.35 MB)
# Trainable params: 614856 (2.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define a learning rate schedule function
def lr_schedule(epoch):
    if epoch < 100:
        return 0.001  # Initial learning rate for the first 100 epochs
    elif epoch < 200:
        return 0.0001  # Lower learning rate for the next 100 epochs
    else:
        return 0.00001  # Further lower learning rate for subsequent epochs

# Create a learning rate scheduler callback
lr_scheduler = LearningRateScheduler(lr_schedule)

# Compile the model with an optimizer (e.g., Adam) and loss function
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.FalseNegatives(), tf.keras.metrics.FalsePositives()])

# Train the model with the learning rate scheduler callback
history = model.fit(x_train, y_train, epochs=1000, verbose=2, callbacks=[lr_scheduler])

# Evaluate the model on the test data
test_loss, test_accuracy, false_negatives, false_positives = model.evaluate(x_test, y_test)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
print(f"False Negatives: {false_negatives:.0f}")
print(f"False Positives: {false_positives:.0f}")

# Make predictions on test data
y_pred = model.predict(x_test)
y_pred_binary = (y_pred >= 0.5).astype(int)

# Calculate confusion matrix
confusion = confusion_matrix(y_test, y_pred_binary)
print("Confusion Matrix:")
print(confusion)
# Out:
# Epoch 1/1000
# 2/2 - 8s - loss: 25.3545 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 8s/epoch - 4s/step
# Epoch 2/1000
# 2/2 - 0s - loss: 13.8587 - accuracy: 0.4167 - false_negatives_2: 17.0000 - false_positives_2: 11.0000 - lr: 0.0010 - 57ms/epoch - 28ms/step
# Epoch 3/1000
# 2/2 - 0s - loss: 16.5835 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 4/1000
# 2/2 - 0s - loss: 37.4876 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 59ms/epoch - 30ms/step
# Epoch 5/1000
# 2/2 - 0s - loss: 20.0198 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 6/1000
# 2/2 - 0s - loss: 8.5338 - accuracy: 0.7500 - false_negatives_2: 1.0000 - false_positives_2: 11.0000 - lr: 0.0010 - 63ms/epoch - 31ms/step
# Epoch 7/1000
# 2/2 - 0s - loss: 14.4662 - accuracy: 0.5833 - false_negatives_2: 4.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 55ms/epoch - 27ms/step
# Epoch 8/1000
# 2/2 - 0s - loss: 15.2069 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 60ms/epoch - 30ms/step
# Epoch 9/1000
# 2/2 - 0s - loss: 17.1177 - accuracy: 0.5208 - false_negatives_2: 7.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 55ms/epoch - 28ms/step
# Epoch 10/1000
# 2/2 - 0s - loss: 260.0130 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 63ms/epoch - 32ms/step
# Epoch 11/1000
# 2/2 - 0s - loss: 17.9795 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 59ms/epoch - 29ms/step
# Epoch 12/1000
# 2/2 - 0s - loss: 21.4233 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 75ms/epoch - 38ms/step
# Epoch 13/1000
# 2/2 - 0s - loss: 22.9559 - accuracy: 0.2917 - false_negatives_2: 26.0000 - false_positives_2: 8.0000 - lr: 0.0010 - 64ms/epoch - 32ms/step
# Epoch 14/1000
# 2/2 - 0s - loss: 51.5720 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 57ms/epoch - 29ms/step
# Epoch 15/1000
# 2/2 - 0s - loss: 39.8966 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 0.0010 - 57ms/epoch - 28ms/step
# Epoch 16/1000
# 2/2 - 0s - loss: 14.0138 - accuracy: 0.3958 - false_negatives_2: 20.0000 - false_positives_2: 9.0000 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 17/1000
# 2/2 - 0s - loss: 203.2318 - accuracy: 0.2917 - false_negatives_2: 32.0000 - false_positives_2: 2.0000 - lr: 0.0010 - 63ms/epoch - 32ms/step
# Epoch 18/1000
# 2/2 - 0s - loss: 32.1592 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 55ms/epoch - 27ms/step
# Epoch 19/1000
# 2/2 - 0s - loss: 20.1877 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 0.0010 - 62ms/epoch - 31ms/step
# Epoch 20/1000
# 2/2 - 0s - loss: 13.2869 - accuracy: 0.1667 - false_negatives_2: 24.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 21/1000
# 2/2 - 0s - loss: 7.7611 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 59ms/epoch - 29ms/step
# Epoch 22/1000
# 2/2 - 0s - loss: 15.0319 - accuracy: 0.4375 - false_negatives_2: 12.0000 - false_positives_2: 15.0000 - lr: 0.0010 - 68ms/epoch - 34ms/step
# Epoch 23/1000
# 2/2 - 0s - loss: 40.6958 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 0.0010 - 60ms/epoch - 30ms/step
# Epoch 24/1000
# 2/2 - 0s - loss: 11.0361 - accuracy: 0.3125 - false_negatives_2: 32.0000 - false_positives_2: 1.0000 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 25/1000
# 2/2 - 0s - loss: 60.7495 - accuracy: 0.5208 - false_negatives_2: 7.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 61ms/epoch - 31ms/step
# Epoch 26/1000
# 2/2 - 0s - loss: 7.4960 - accuracy: 0.4792 - false_negatives_2: 25.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 69ms/epoch - 34ms/step
# Epoch 27/1000
# 2/2 - 0s - loss: 28.0285 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 67ms/epoch - 34ms/step
# Epoch 28/1000
# 2/2 - 0s - loss: 41.2509 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 0.0010 - 63ms/epoch - 32ms/step
# Epoch 29/1000
# 2/2 - 0s - loss: 15.4664 - accuracy: 0.5833 - false_negatives_2: 7.0000 - false_positives_2: 13.0000 - lr: 0.0010 - 54ms/epoch - 27ms/step
# Epoch 30/1000
# 2/2 - 0s - loss: 9.1393 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 0.0010 - 54ms/epoch - 27ms/step
# Epoch 31/1000
# 2/2 - 0s - loss: 8.6808 - accuracy: 0.5000 - false_negatives_2: 8.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 60ms/epoch - 30ms/step
# Epoch 32/1000
# 2/2 - 0s - loss: 8.2037 - accuracy: 0.4375 - false_negatives_2: 21.0000 - false_positives_2: 6.0000 - lr: 0.0010 - 59ms/epoch - 30ms/step
# Epoch 33/1000
# 2/2 - 0s - loss: 8.6204 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 59ms/epoch - 30ms/step
# Epoch 34/1000
# 2/2 - 0s - loss: 23.5333 - accuracy: 0.5208 - false_negatives_2: 7.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 59ms/epoch - 30ms/step
# Epoch 35/1000
# 2/2 - 0s - loss: 10.4799 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 36/1000
# 2/2 - 0s - loss: 28.5401 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 0.0010 - 57ms/epoch - 28ms/step
# Epoch 37/1000
# 2/2 - 0s - loss: 6.9550 - accuracy: 0.6250 - false_negatives_2: 14.0000 - false_positives_2: 4.0000 - lr: 0.0010 - 65ms/epoch - 33ms/step
# Epoch 38/1000
# 2/2 - 0s - loss: 13.3399 - accuracy: 0.6458 - false_negatives_2: 8.0000 - false_positives_2: 9.0000 - lr: 0.0010 - 60ms/epoch - 30ms/step
# Epoch 39/1000
# 2/2 - 0s - loss: 14.5577 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 66ms/epoch - 33ms/step
# Epoch 40/1000
# 2/2 - 0s - loss: 42.2600 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 69ms/epoch - 35ms/step
# Epoch 41/1000
# 2/2 - 0s - loss: 14.3825 - accuracy: 0.4583 - false_negatives_2: 12.0000 - false_positives_2: 14.0000 - lr: 0.0010 - 59ms/epoch - 29ms/step
# Epoch 42/1000
# 2/2 - 0s - loss: 10.5175 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 64ms/epoch - 32ms/step
# Epoch 43/1000
# 2/2 - 0s - loss: 45.9660 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 0.0010 - 68ms/epoch - 34ms/step
# Epoch 44/1000
# 2/2 - 0s - loss: 14.9761 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 61ms/epoch - 30ms/step
# Epoch 45/1000
# 2/2 - 0s - loss: 27.9095 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 46/1000
# 2/2 - 0s - loss: 40.6382 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 47/1000
# 2/2 - 0s - loss: 9.7079 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 57ms/epoch - 29ms/step
# Epoch 48/1000
# 2/2 - 0s - loss: 11.8765 - accuracy: 0.5208 - false_negatives_2: 12.0000 - false_positives_2: 11.0000 - lr: 0.0010 - 63ms/epoch - 32ms/step
# Epoch 49/1000
# 2/2 - 0s - loss: 19.2436 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 0.0010 - 55ms/epoch - 27ms/step
# Epoch 50/1000
# 2/2 - 0s - loss: 7.9630 - accuracy: 0.5417 - false_negatives_2: 6.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 51/1000
# 2/2 - 0s - loss: 7.5011 - accuracy: 0.5625 - false_negatives_2: 16.0000 - false_positives_2: 5.0000 - lr: 0.0010 - 57ms/epoch - 28ms/step
# Epoch 52/1000
# 2/2 - 0s - loss: 10.6238 - accuracy: 0.7292 - false_negatives_2: 2.0000 - false_positives_2: 11.0000 - lr: 0.0010 - 65ms/epoch - 33ms/step
# Epoch 53/1000
# 2/2 - 0s - loss: 81.9387 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 60ms/epoch - 30ms/step
# Epoch 54/1000
# 2/2 - 0s - loss: 7.2495 - accuracy: 0.4375 - false_negatives_2: 12.0000 - false_positives_2: 15.0000 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 55/1000
# 2/2 - 0s - loss: 10.2348 - accuracy: 0.3750 - false_negatives_2: 23.0000 - false_positives_2: 7.0000 - lr: 0.0010 - 53ms/epoch - 27ms/step
# Epoch 56/1000
# 2/2 - 0s - loss: 15.6030 - accuracy: 0.5000 - false_negatives_2: 16.0000 - false_positives_2: 8.0000 - lr: 0.0010 - 54ms/epoch - 27ms/step
# Epoch 57/1000
# 2/2 - 0s - loss: 28.2907 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 63ms/epoch - 32ms/step
# Epoch 58/1000
# 2/2 - 0s - loss: 15.5146 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 0.0010 - 66ms/epoch - 33ms/step
# Epoch 59/1000
# 2/2 - 0s - loss: 19.3634 - accuracy: 0.5208 - false_negatives_2: 11.0000 - false_positives_2: 12.0000 - lr: 0.0010 - 53ms/epoch - 26ms/step
# Epoch 60/1000
# 2/2 - 0s - loss: 37.4434 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 0.0010 - 55ms/epoch - 27ms/step
# Epoch 61/1000
# 2/2 - 0s - loss: 25.5265 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 62/1000
# 2/2 - 0s - loss: 66.5382 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 66ms/epoch - 33ms/step
# Epoch 63/1000
# 2/2 - 0s - loss: 7.3946 - accuracy: 0.3750 - false_negatives_2: 17.0000 - false_positives_2: 13.0000 - lr: 0.0010 - 54ms/epoch - 27ms/step
# Epoch 64/1000
# 2/2 - 0s - loss: 55.4779 - accuracy: 0.5833 - false_negatives_2: 7.0000 - false_positives_2: 13.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 65/1000
# 2/2 - 0s - loss: 35.8480 - accuracy: 0.5000 - false_negatives_2: 12.0000 - false_positives_2: 12.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 66/1000
# 2/2 - 0s - loss: 11.3653 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 0.0010 - 57ms/epoch - 29ms/step
# Epoch 67/1000
# 2/2 - 0s - loss: 76.6214 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 0.0010 - 65ms/epoch - 33ms/step
# Epoch 68/1000
# 2/2 - 0s - loss: 26.2823 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 0.0010 - 55ms/epoch - 28ms/step
# Epoch 69/1000
# 2/2 - 0s - loss: 8.3664 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 71ms/epoch - 36ms/step
# Epoch 70/1000
# 2/2 - 0s - loss: 17.1591 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 71/1000
# 2/2 - 0s - loss: 34.6990 - accuracy: 0.4583 - false_negatives_2: 10.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 53ms/epoch - 26ms/step
# Epoch 72/1000
# 2/2 - 0s - loss: 10.6704 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 73/1000
# 2/2 - 0s - loss: 13.7678 - accuracy: 0.5208 - false_negatives_2: 18.0000 - false_positives_2: 5.0000 - lr: 0.0010 - 65ms/epoch - 33ms/step
# Epoch 74/1000
# 2/2 - 0s - loss: 147.6290 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 70ms/epoch - 35ms/step
# Epoch 75/1000
# 2/2 - 0s - loss: 15.9944 - accuracy: 0.4375 - false_negatives_2: 27.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 76/1000
# 2/2 - 0s - loss: 26.3988 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 57ms/epoch - 28ms/step
# Epoch 77/1000
# 2/2 - 0s - loss: 16.2198 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 78/1000
# 2/2 - 0s - loss: 36.0507 - accuracy: 0.3542 - false_negatives_2: 25.0000 - false_positives_2: 6.0000 - lr: 0.0010 - 56ms/epoch - 28ms/step
# Epoch 79/1000
# 2/2 - 0s - loss: 10.7240 - accuracy: 0.7083 - false_negatives_2: 3.0000 - false_positives_2: 11.0000 - lr: 0.0010 - 55ms/epoch - 27ms/step
# Epoch 80/1000
# 2/2 - 0s - loss: 19.9480 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 55ms/epoch - 28ms/step
# Epoch 81/1000
# 2/2 - 0s - loss: 46.2787 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 0.0010 - 59ms/epoch - 29ms/step
# Epoch 82/1000
# 2/2 - 0s - loss: 15.4192 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 54ms/epoch - 27ms/step
# Epoch 83/1000
# 2/2 - 0s - loss: 13.4140 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 57ms/epoch - 29ms/step
# Epoch 84/1000
# 2/2 - 0s - loss: 29.3556 - accuracy: 0.3750 - false_negatives_2: 23.0000 - false_positives_2: 7.0000 - lr: 0.0010 - 52ms/epoch - 26ms/step
# Epoch 85/1000
# 2/2 - 0s - loss: 11.9516 - accuracy: 0.6042 - false_negatives_2: 3.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 63ms/epoch - 31ms/step
# Epoch 86/1000
# 2/2 - 0s - loss: 11.7191 - accuracy: 0.5833 - false_negatives_2: 18.0000 - false_positives_2: 2.0000 - lr: 0.0010 - 57ms/epoch - 28ms/step
# Epoch 87/1000
# 2/2 - 0s - loss: 53.0797 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 0.0010 - 54ms/epoch - 27ms/step
# Epoch 88/1000
# 2/2 - 0s - loss: 13.4600 - accuracy: 0.5625 - false_negatives_2: 18.0000 - false_positives_2: 3.0000 - lr: 0.0010 - 57ms/epoch - 29ms/step
# Epoch 89/1000
# 2/2 - 0s - loss: 14.3503 - accuracy: 0.3333 - false_negatives_2: 24.0000 - false_positives_2: 8.0000 - lr: 0.0010 - 57ms/epoch - 29ms/step
# Epoch 90/1000
# 2/2 - 0s - loss: 57.9228 - accuracy: 0.4583 - false_negatives_2: 22.0000 - false_positives_2: 4.0000 - lr: 0.0010 - 76ms/epoch - 38ms/step
# Epoch 91/1000
# 2/2 - 0s - loss: 9.5120 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 0.0010 - 57ms/epoch - 29ms/step
# Epoch 92/1000
# 2/2 - 0s - loss: 35.1459 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 57ms/epoch - 29ms/step
# Epoch 93/1000
# 2/2 - 0s - loss: 8.3624 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 0.0010 - 55ms/epoch - 28ms/step
# Epoch 94/1000
# 2/2 - 0s - loss: 24.1542 - accuracy: 0.5625 - false_negatives_2: 5.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 54ms/epoch - 27ms/step
# Epoch 95/1000
# 2/2 - 0s - loss: 20.3436 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 96/1000
# 2/2 - 0s - loss: 11.1546 - accuracy: 0.6458 - false_negatives_2: 1.0000 - false_positives_2: 16.0000 - lr: 0.0010 - 55ms/epoch - 27ms/step
# Epoch 97/1000
# 2/2 - 0s - loss: 7.1790 - accuracy: 0.6875 - false_negatives_2: 7.0000 - false_positives_2: 8.0000 - lr: 0.0010 - 58ms/epoch - 29ms/step
# Epoch 98/1000
# 2/2 - 0s - loss: 18.0100 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 0.0010 - 55ms/epoch - 28ms/step
# Epoch 99/1000
# 2/2 - 0s - loss: 17.6610 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 59ms/epoch - 30ms/step
# Epoch 100/1000
# 2/2 - 0s - loss: 34.4003 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 0.0010 - 68ms/epoch - 34ms/step
# Epoch 101/1000
# 2/2 - 0s - loss: 10.2171 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 61ms/epoch - 31ms/step
# Epoch 102/1000
# 2/2 - 0s - loss: 17.2086 - accuracy: 0.7500 - false_negatives_2: 1.0000 - false_positives_2: 11.0000 - lr: 1.0000e-04 - 55ms/epoch - 28ms/step
# Epoch 103/1000
# 2/2 - 0s - loss: 8.1433 - accuracy: 0.5625 - false_negatives_2: 5.0000 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 56ms/epoch - 28ms/step
# Epoch 104/1000
# 2/2 - 0s - loss: 40.6611 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-04 - 57ms/epoch - 28ms/step
# Epoch 105/1000
# 2/2 - 0s - loss: 8.5308 - accuracy: 0.4375 - false_negatives_2: 22.0000 - false_positives_2: 5.0000 - lr: 1.0000e-04 - 60ms/epoch - 30ms/step
# Epoch 106/1000
# 2/2 - 0s - loss: 6.8284 - accuracy: 0.5833 - false_negatives_2: 4.0000 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 66ms/epoch - 33ms/step
# Epoch 107/1000
# 2/2 - 0s - loss: 14.0440 - accuracy: 0.5000 - false_negatives_2: 17.0000 - false_positives_2: 7.0000 - lr: 1.0000e-04 - 52ms/epoch - 26ms/step
# Epoch 108/1000
# 2/2 - 0s - loss: 37.6079 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-04 - 55ms/epoch - 27ms/step
# Epoch 109/1000
# 2/2 - 0s - loss: 36.2631 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-04 - 53ms/epoch - 27ms/step
# Epoch 110/1000
# 2/2 - 0s - loss: 16.6091 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 60ms/epoch - 30ms/step
# Epoch 111/1000
# 2/2 - 0s - loss: 30.7384 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 55ms/epoch - 28ms/step
# Epoch 112/1000
# 2/2 - 0s - loss: 15.7710 - accuracy: 0.3125 - false_negatives_2: 25.0000 - false_positives_2: 8.0000 - lr: 1.0000e-04 - 54ms/epoch - 27ms/step
# Epoch 113/1000
# 2/2 - 0s - loss: 9.3689 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-04 - 56ms/epoch - 28ms/step
# Epoch 114/1000
# 2/2 - 0s - loss: 8.5525 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 1.0000e-04 - 59ms/epoch - 29ms/step
# Epoch 115/1000
# 2/2 - 0s - loss: 10.4826 - accuracy: 0.7500 - false_negatives_2: 2.0000 - false_positives_2: 10.0000 - lr: 1.0000e-04 - 58ms/epoch - 29ms/step
# Epoch 116/1000
# 2/2 - 0s - loss: 43.0881 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-04 - 64ms/epoch - 32ms/step
# Epoch 117/1000
# 2/2 - 0s - loss: 13.1273 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 55ms/epoch - 27ms/step
# Epoch 118/1000
# 2/2 - 0s - loss: 81.5265 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-04 - 58ms/epoch - 29ms/step
# Epoch 119/1000
# 2/2 - 0s - loss: 9.3297 - accuracy: 0.3542 - false_negatives_2: 31.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 57ms/epoch - 29ms/step
# Epoch 120/1000
# 2/2 - 0s - loss: 21.1164 - accuracy: 0.6667 - false_negatives_2: 1.0000 - false_positives_2: 15.0000 - lr: 1.0000e-04 - 60ms/epoch - 30ms/step
# Epoch 121/1000
# 2/2 - 0s - loss: 8.2325 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 57ms/epoch - 29ms/step
# Epoch 122/1000
# 2/2 - 0s - loss: 42.0917 - accuracy: 0.3750 - false_negatives_2: 23.0000 - false_positives_2: 7.0000 - lr: 1.0000e-04 - 68ms/epoch - 34ms/step
# Epoch 123/1000
# 2/2 - 0s - loss: 7.5760 - accuracy: 0.5833 - false_negatives_2: 5.0000 - false_positives_2: 15.0000 - lr: 1.0000e-04 - 62ms/epoch - 31ms/step
# Epoch 124/1000
# 2/2 - 0s - loss: 27.9198 - accuracy: 0.2917 - false_negatives_2: 30.0000 - false_positives_2: 4.0000 - lr: 1.0000e-04 - 56ms/epoch - 28ms/step
# Epoch 125/1000
# 2/2 - 0s - loss: 269.1946 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 60ms/epoch - 30ms/step
# Epoch 126/1000
# 2/2 - 0s - loss: 43.1946 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-04 - 58ms/epoch - 29ms/step
# Epoch 127/1000
# 2/2 - 0s - loss: 39.8090 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-04 - 59ms/epoch - 30ms/step
# Epoch 128/1000
# 2/2 - 0s - loss: 30.8990 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 54ms/epoch - 27ms/step
# Epoch 129/1000
# 2/2 - 0s - loss: 69.8144 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-04 - 55ms/epoch - 28ms/step
# Epoch 130/1000
# 2/2 - 0s - loss: 9.1718 - accuracy: 0.3542 - false_negatives_2: 23.0000 - false_positives_2: 8.0000 - lr: 1.0000e-04 - 69ms/epoch - 34ms/step
# Epoch 131/1000
# 2/2 - 0s - loss: 35.0584 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 57ms/epoch - 29ms/step
# Epoch 132/1000
# 2/2 - 0s - loss: 67.6537 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-04 - 59ms/epoch - 30ms/step
# Epoch 133/1000
# 2/2 - 0s - loss: 19.3147 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 56ms/epoch - 28ms/step
# Epoch 134/1000
# 2/2 - 0s - loss: 23.1200 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 61ms/epoch - 31ms/step
# Epoch 135/1000
# 2/2 - 0s - loss: 102.5106 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 72ms/epoch - 36ms/step
# Epoch 136/1000
# 2/2 - 0s - loss: 11.0338 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 57ms/epoch - 28ms/step
# Epoch 137/1000
# 2/2 - 0s - loss: 10.5917 - accuracy: 0.4792 - false_negatives_2: 21.0000 - false_positives_2: 4.0000 - lr: 1.0000e-04 - 65ms/epoch - 32ms/step
# Epoch 138/1000
# 2/2 - 0s - loss: 23.1089 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-04 - 54ms/epoch - 27ms/step
# Epoch 139/1000
# 2/2 - 0s - loss: 6.5004 - accuracy: 0.7083 - false_negatives_2: 3.0000 - false_positives_2: 11.0000 - lr: 1.0000e-04 - 56ms/epoch - 28ms/step
# Epoch 140/1000
# 2/2 - 0s - loss: 22.8312 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 59ms/epoch - 30ms/step
# Epoch 141/1000
# 2/2 - 0s - loss: 98.9342 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-04 - 58ms/epoch - 29ms/step
# Epoch 142/1000
# 2/2 - 0s - loss: 24.0267 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 54ms/epoch - 27ms/step
# Epoch 143/1000
# 2/2 - 0s - loss: 8.8388 - accuracy: 0.5625 - false_negatives_2: 5.0000 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 54ms/epoch - 27ms/step
# Epoch 144/1000
# 2/2 - 0s - loss: 59.8102 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 55ms/epoch - 28ms/step
# Epoch 145/1000
# 2/2 - 0s - loss: 17.3351 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 72ms/epoch - 36ms/step
# Epoch 146/1000
# 2/2 - 0s - loss: 11.0466 - accuracy: 0.6458 - false_negatives_2: 1.0000 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 75ms/epoch - 37ms/step
# Epoch 147/1000
# 2/2 - 0s - loss: 87.6741 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 103ms/epoch - 52ms/step
# Epoch 148/1000
# 2/2 - 0s - loss: 9.6459 - accuracy: 0.3333 - false_negatives_2: 24.0000 - false_positives_2: 8.0000 - lr: 1.0000e-04 - 114ms/epoch - 57ms/step
# Epoch 149/1000
# 2/2 - 0s - loss: 13.6392 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 114ms/epoch - 57ms/step
# Epoch 150/1000
# 2/2 - 0s - loss: 36.1144 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-04 - 108ms/epoch - 54ms/step
# Epoch 151/1000
# 2/2 - 0s - loss: 25.5185 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-04 - 111ms/epoch - 55ms/step
# Epoch 152/1000
# 2/2 - 0s - loss: 17.1509 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 119ms/epoch - 60ms/step
# Epoch 153/1000
# 2/2 - 0s - loss: 48.2632 - accuracy: 0.4583 - false_negatives_2: 13.0000 - false_positives_2: 13.0000 - lr: 1.0000e-04 - 113ms/epoch - 56ms/step
# Epoch 154/1000
# 2/2 - 0s - loss: 25.4142 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-04 - 117ms/epoch - 58ms/step
# Epoch 155/1000
# 2/2 - 0s - loss: 17.9025 - accuracy: 0.4792 - false_negatives_2: 25.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 116ms/epoch - 58ms/step
# Epoch 156/1000
# 2/2 - 0s - loss: 27.7633 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-04 - 116ms/epoch - 58ms/step
# Epoch 157/1000
# 2/2 - 0s - loss: 18.4270 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-04 - 117ms/epoch - 59ms/step
# Epoch 158/1000
# 2/2 - 0s - loss: 39.7159 - accuracy: 0.3125 - false_negatives_2: 22.0000 - false_positives_2: 11.0000 - lr: 1.0000e-04 - 118ms/epoch - 59ms/step
# Epoch 159/1000
# 2/2 - 0s - loss: 26.7454 - accuracy: 0.3750 - false_negatives_2: 23.0000 - false_positives_2: 7.0000 - lr: 1.0000e-04 - 122ms/epoch - 61ms/step
# Epoch 160/1000
# 2/2 - 0s - loss: 81.4337 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 115ms/epoch - 58ms/step
# Epoch 161/1000
# 2/2 - 0s - loss: 21.5471 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-04 - 114ms/epoch - 57ms/step
# Epoch 162/1000
# 2/2 - 0s - loss: 9.8345 - accuracy: 0.3542 - false_negatives_2: 27.0000 - false_positives_2: 4.0000 - lr: 1.0000e-04 - 111ms/epoch - 56ms/step
# Epoch 163/1000
# 2/2 - 0s - loss: 26.3830 - accuracy: 0.5833 - false_negatives_2: 18.0000 - false_positives_2: 2.0000 - lr: 1.0000e-04 - 114ms/epoch - 57ms/step
# Epoch 164/1000
# 2/2 - 0s - loss: 29.0843 - accuracy: 0.6458 - false_negatives_2: 11.0000 - false_positives_2: 6.0000 - lr: 1.0000e-04 - 118ms/epoch - 59ms/step
# Epoch 165/1000
# 2/2 - 0s - loss: 13.0072 - accuracy: 0.6458 - false_negatives_2: 4.0000 - false_positives_2: 13.0000 - lr: 1.0000e-04 - 125ms/epoch - 62ms/step
# Epoch 166/1000
# 2/2 - 0s - loss: 25.7644 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 123ms/epoch - 61ms/step
# Epoch 167/1000
# 2/2 - 0s - loss: 12.6669 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 119ms/epoch - 59ms/step
# Epoch 168/1000
# 2/2 - 0s - loss: 119.6345 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-04 - 125ms/epoch - 63ms/step
# Epoch 169/1000
# 2/2 - 0s - loss: 58.7134 - accuracy: 0.3958 - false_negatives_2: 24.0000 - false_positives_2: 5.0000 - lr: 1.0000e-04 - 121ms/epoch - 60ms/step
# Epoch 170/1000
# 2/2 - 0s - loss: 27.8671 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-04 - 119ms/epoch - 60ms/step
# Epoch 171/1000
# 2/2 - 0s - loss: 16.8235 - accuracy: 0.5208 - false_negatives_2: 23.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 114ms/epoch - 57ms/step
# Epoch 172/1000
# 2/2 - 0s - loss: 17.7877 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 123ms/epoch - 62ms/step
# Epoch 173/1000
# 2/2 - 0s - loss: 18.3768 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 114ms/epoch - 57ms/step
# Epoch 174/1000
# 2/2 - 0s - loss: 8.3054 - accuracy: 0.2500 - false_negatives_2: 24.0000 - false_positives_2: 12.0000 - lr: 1.0000e-04 - 114ms/epoch - 57ms/step
# Epoch 175/1000
# 2/2 - 0s - loss: 37.2586 - accuracy: 0.2708 - false_negatives_2: 27.0000 - false_positives_2: 8.0000 - lr: 1.0000e-04 - 120ms/epoch - 60ms/step
# Epoch 176/1000
# 2/2 - 0s - loss: 15.7615 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 117ms/epoch - 58ms/step
# Epoch 177/1000
# 2/2 - 0s - loss: 15.1579 - accuracy: 0.6458 - false_negatives_2: 7.0000 - false_positives_2: 10.0000 - lr: 1.0000e-04 - 123ms/epoch - 62ms/step
# Epoch 178/1000
# 2/2 - 0s - loss: 37.4945 - accuracy: 0.3750 - false_negatives_2: 23.0000 - false_positives_2: 7.0000 - lr: 1.0000e-04 - 119ms/epoch - 59ms/step
# Epoch 179/1000
# 2/2 - 0s - loss: 13.4019 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 125ms/epoch - 62ms/step
# Epoch 180/1000
# 2/2 - 0s - loss: 15.4907 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-04 - 124ms/epoch - 62ms/step
# Epoch 181/1000
# 2/2 - 0s - loss: 18.4366 - accuracy: 0.3333 - false_negatives_2: 23.0000 - false_positives_2: 9.0000 - lr: 1.0000e-04 - 114ms/epoch - 57ms/step
# Epoch 182/1000
# 2/2 - 0s - loss: 31.0395 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-04 - 100ms/epoch - 50ms/step
# Epoch 183/1000
# 2/2 - 0s - loss: 7.1559 - accuracy: 0.6875 - false_negatives_2: 0.0000e+00 - false_positives_2: 15.0000 - lr: 1.0000e-04 - 59ms/epoch - 30ms/step
# Epoch 184/1000
# 2/2 - 0s - loss: 58.3537 - accuracy: 0.4583 - false_negatives_2: 13.0000 - false_positives_2: 13.0000 - lr: 1.0000e-04 - 65ms/epoch - 32ms/step
# Epoch 185/1000
# 2/2 - 0s - loss: 8.3644 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 54ms/epoch - 27ms/step
# Epoch 186/1000
# 2/2 - 0s - loss: 12.5887 - accuracy: 0.4792 - false_negatives_2: 20.0000 - false_positives_2: 5.0000 - lr: 1.0000e-04 - 54ms/epoch - 27ms/step
# Epoch 187/1000
# 2/2 - 0s - loss: 11.6164 - accuracy: 0.3958 - false_negatives_2: 16.0000 - false_positives_2: 13.0000 - lr: 1.0000e-04 - 56ms/epoch - 28ms/step
# Epoch 188/1000
# 2/2 - 0s - loss: 26.2738 - accuracy: 0.4792 - false_negatives_2: 9.0000 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 62ms/epoch - 31ms/step
# Epoch 189/1000
# 2/2 - 0s - loss: 28.4826 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 56ms/epoch - 28ms/step
# Epoch 190/1000
# 2/2 - 0s - loss: 17.0223 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 58ms/epoch - 29ms/step
# Epoch 191/1000
# 2/2 - 0s - loss: 108.6366 - accuracy: 0.5000 - false_negatives_2: 24.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 62ms/epoch - 31ms/step
# Epoch 192/1000
# 2/2 - 0s - loss: 14.9969 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-04 - 60ms/epoch - 30ms/step
# Epoch 193/1000
# 2/2 - 0s - loss: 62.5769 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 57ms/epoch - 28ms/step
# Epoch 194/1000
# 2/2 - 0s - loss: 7.6230 - accuracy: 0.4583 - false_negatives_2: 14.0000 - false_positives_2: 12.0000 - lr: 1.0000e-04 - 55ms/epoch - 27ms/step
# Epoch 195/1000
# 2/2 - 0s - loss: 29.4217 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-04 - 59ms/epoch - 30ms/step
# Epoch 196/1000
# 2/2 - 0s - loss: 12.0102 - accuracy: 0.3750 - false_negatives_2: 30.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 55ms/epoch - 28ms/step
# Epoch 197/1000
# 2/2 - 0s - loss: 7.7371 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-04 - 60ms/epoch - 30ms/step
# Epoch 198/1000
# 2/2 - 0s - loss: 25.7012 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-04 - 54ms/epoch - 27ms/step
# Epoch 199/1000
# 2/2 - 0s - loss: 30.0819 - accuracy: 0.5000 - false_negatives_2: 12.0000 - false_positives_2: 12.0000 - lr: 1.0000e-04 - 56ms/epoch - 28ms/step
# Epoch 200/1000
# 2/2 - 0s - loss: 11.0150 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-04 - 67ms/epoch - 34ms/step
# Epoch 201/1000
# 2/2 - 0s - loss: 9.5170 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 202/1000
# 2/2 - 0s - loss: 30.5592 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 203/1000
# 2/2 - 0s - loss: 27.6912 - accuracy: 0.6042 - false_negatives_2: 19.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 59ms/epoch - 30ms/step
# Epoch 204/1000
# 2/2 - 0s - loss: 27.8235 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 63ms/epoch - 31ms/step
# Epoch 205/1000
# 2/2 - 0s - loss: 68.6542 - accuracy: 0.4583 - false_negatives_2: 13.0000 - false_positives_2: 13.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 206/1000
# 2/2 - 0s - loss: 16.1296 - accuracy: 0.6458 - false_negatives_2: 12.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 61ms/epoch - 31ms/step
# Epoch 207/1000
# 2/2 - 0s - loss: 8.1638 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 208/1000
# 2/2 - 0s - loss: 25.4530 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 71ms/epoch - 35ms/step
# Epoch 209/1000
# 2/2 - 0s - loss: 22.7052 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 57ms/epoch - 29ms/step
# Epoch 210/1000
# 2/2 - 0s - loss: 162.0873 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 211/1000
# 2/2 - 0s - loss: 12.9000 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 212/1000
# 2/2 - 0s - loss: 20.7213 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 57ms/epoch - 28ms/step
# Epoch 213/1000
# 2/2 - 0s - loss: 13.3701 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 59ms/epoch - 30ms/step
# Epoch 214/1000
# 2/2 - 0s - loss: 19.8908 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 65ms/epoch - 33ms/step
# Epoch 215/1000
# 2/2 - 0s - loss: 11.4441 - accuracy: 0.6458 - false_negatives_2: 1.0000 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 67ms/epoch - 33ms/step
# Epoch 216/1000
# 2/2 - 0s - loss: 37.9158 - accuracy: 0.7500 - false_negatives_2: 6.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 63ms/epoch - 31ms/step
# Epoch 217/1000
# 2/2 - 0s - loss: 13.9833 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 218/1000
# 2/2 - 0s - loss: 19.8033 - accuracy: 0.3542 - false_negatives_2: 31.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 72ms/epoch - 36ms/step
# Epoch 219/1000
# 2/2 - 0s - loss: 11.7823 - accuracy: 0.6875 - false_negatives_2: 12.0000 - false_positives_2: 3.0000 - lr: 1.0000e-05 - 57ms/epoch - 29ms/step
# Epoch 220/1000
# 2/2 - 0s - loss: 41.8134 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-05 - 59ms/epoch - 30ms/step
# Epoch 221/1000
# 2/2 - 0s - loss: 15.5601 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 61ms/epoch - 30ms/step
# Epoch 222/1000
# 2/2 - 0s - loss: 11.0160 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 223/1000
# 2/2 - 0s - loss: 34.8416 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 224/1000
# 2/2 - 0s - loss: 8.9629 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 55ms/epoch - 28ms/step
# Epoch 225/1000
# 2/2 - 0s - loss: 48.5116 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 1.0000e-05 - 54ms/epoch - 27ms/step
# Epoch 226/1000
# 2/2 - 0s - loss: 52.1761 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 227/1000
# 2/2 - 0s - loss: 57.1822 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 228/1000
# 2/2 - 0s - loss: 9.9060 - accuracy: 0.8333 - false_negatives_2: 0.0000e+00 - false_positives_2: 8.0000 - lr: 1.0000e-05 - 53ms/epoch - 26ms/step
# Epoch 229/1000
# 2/2 - 0s - loss: 33.4960 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 54ms/epoch - 27ms/step
# Epoch 230/1000
# 2/2 - 0s - loss: 10.4214 - accuracy: 0.4583 - false_negatives_2: 24.0000 - false_positives_2: 2.0000 - lr: 1.0000e-05 - 55ms/epoch - 28ms/step
# Epoch 231/1000
# 2/2 - 0s - loss: 22.5953 - accuracy: 0.5625 - false_negatives_2: 15.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 72ms/epoch - 36ms/step
# Epoch 232/1000
# 2/2 - 0s - loss: 66.5170 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 233/1000
# 2/2 - 0s - loss: 26.8900 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 234/1000
# 2/2 - 0s - loss: 17.4331 - accuracy: 0.2500 - false_negatives_2: 31.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 54ms/epoch - 27ms/step
# Epoch 235/1000
# 2/2 - 0s - loss: 13.3095 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 236/1000
# 2/2 - 0s - loss: 14.7742 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 237/1000
# 2/2 - 0s - loss: 8.3242 - accuracy: 0.7292 - false_negatives_2: 11.0000 - false_positives_2: 2.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 238/1000
# 2/2 - 0s - loss: 81.9402 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 239/1000
# 2/2 - 0s - loss: 12.8680 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 52ms/epoch - 26ms/step
# Epoch 240/1000
# 2/2 - 0s - loss: 14.3224 - accuracy: 0.5417 - false_negatives_2: 7.0000 - false_positives_2: 15.0000 - lr: 1.0000e-05 - 52ms/epoch - 26ms/step
# Epoch 241/1000
# 2/2 - 0s - loss: 11.2354 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 242/1000
# 2/2 - 0s - loss: 17.2673 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 54ms/epoch - 27ms/step
# Epoch 243/1000
# 2/2 - 0s - loss: 28.0449 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 244/1000
# 2/2 - 0s - loss: 21.7016 - accuracy: 0.4583 - false_negatives_2: 13.0000 - false_positives_2: 13.0000 - lr: 1.0000e-05 - 53ms/epoch - 26ms/step
# Epoch 245/1000
# 2/2 - 0s - loss: 8.1411 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 246/1000
# 2/2 - 0s - loss: 40.3920 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 247/1000
# 2/2 - 0s - loss: 8.2400 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 81ms/epoch - 41ms/step
# Epoch 248/1000
# 2/2 - 0s - loss: 10.4198 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 249/1000
# 2/2 - 0s - loss: 18.1233 - accuracy: 0.2917 - false_negatives_2: 32.0000 - false_positives_2: 2.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 250/1000
# 2/2 - 0s - loss: 24.8007 - accuracy: 0.6667 - false_negatives_2: 11.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 251/1000
# 2/2 - 0s - loss: 28.0606 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 252/1000
# 2/2 - 0s - loss: 23.8652 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 63ms/epoch - 32ms/step
# Epoch 253/1000
# 2/2 - 0s - loss: 24.8060 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 57ms/epoch - 28ms/step
# Epoch 254/1000
# 2/2 - 0s - loss: 15.8372 - accuracy: 0.5208 - false_negatives_2: 11.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 61ms/epoch - 30ms/step
# Epoch 255/1000
# 2/2 - 0s - loss: 206.1360 - accuracy: 0.5000 - false_negatives_2: 12.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 256/1000
# 2/2 - 0s - loss: 7.1985 - accuracy: 0.5833 - false_negatives_2: 18.0000 - false_positives_2: 2.0000 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 257/1000
# 2/2 - 0s - loss: 16.1351 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 258/1000
# 2/2 - 0s - loss: 8.7035 - accuracy: 0.3542 - false_negatives_2: 23.0000 - false_positives_2: 8.0000 - lr: 1.0000e-05 - 57ms/epoch - 28ms/step
# Epoch 259/1000
# 2/2 - 0s - loss: 45.2604 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 54ms/epoch - 27ms/step
# Epoch 260/1000
# 2/2 - 0s - loss: 47.6506 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 53ms/epoch - 27ms/step
# Epoch 261/1000
# 2/2 - 0s - loss: 8.7656 - accuracy: 0.4375 - false_negatives_2: 18.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 262/1000
# 2/2 - 0s - loss: 8.9749 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 68ms/epoch - 34ms/step
# Epoch 263/1000
# 2/2 - 0s - loss: 8.0663 - accuracy: 0.2500 - false_negatives_2: 25.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 264/1000
# 2/2 - 0s - loss: 10.1495 - accuracy: 0.6458 - false_negatives_2: 12.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 265/1000
# 2/2 - 0s - loss: 16.3141 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 266/1000
# 2/2 - 0s - loss: 25.4409 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 66ms/epoch - 33ms/step
# Epoch 267/1000
# 2/2 - 0s - loss: 9.8101 - accuracy: 0.5625 - false_negatives_2: 12.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 65ms/epoch - 33ms/step
# Epoch 268/1000
# 2/2 - 0s - loss: 45.4217 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 65ms/epoch - 32ms/step
# Epoch 269/1000
# 2/2 - 0s - loss: 12.8022 - accuracy: 0.4375 - false_negatives_2: 14.0000 - false_positives_2: 13.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 270/1000
# 2/2 - 0s - loss: 7.7364 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 61ms/epoch - 30ms/step
# Epoch 271/1000
# 2/2 - 0s - loss: 35.1866 - accuracy: 0.3125 - false_negatives_2: 21.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 68ms/epoch - 34ms/step
# Epoch 272/1000
# 2/2 - 0s - loss: 105.5511 - accuracy: 0.2917 - false_negatives_2: 25.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 273/1000
# 2/2 - 0s - loss: 15.2434 - accuracy: 0.6042 - false_negatives_2: 3.0000 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 67ms/epoch - 33ms/step
# Epoch 274/1000
# 2/2 - 0s - loss: 16.0905 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 66ms/epoch - 33ms/step
# Epoch 275/1000
# 2/2 - 0s - loss: 13.8848 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 276/1000
# 2/2 - 0s - loss: 9.1177 - accuracy: 0.3750 - false_negatives_2: 22.0000 - false_positives_2: 8.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 277/1000
# 2/2 - 0s - loss: 18.7198 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 73ms/epoch - 36ms/step
# Epoch 278/1000
# 2/2 - 0s - loss: 12.9945 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 59ms/epoch - 30ms/step
# Epoch 279/1000
# 2/2 - 0s - loss: 140.0862 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 280/1000
# 2/2 - 0s - loss: 8.1098 - accuracy: 0.1667 - false_negatives_2: 31.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 68ms/epoch - 34ms/step
# Epoch 281/1000
# 2/2 - 0s - loss: 15.9004 - accuracy: 0.3750 - false_negatives_2: 23.0000 - false_positives_2: 7.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 282/1000
# 2/2 - 0s - loss: 25.3025 - accuracy: 0.3750 - false_negatives_2: 30.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 65ms/epoch - 32ms/step
# Epoch 283/1000
# 2/2 - 0s - loss: 21.6458 - accuracy: 0.4583 - false_negatives_2: 13.0000 - false_positives_2: 13.0000 - lr: 1.0000e-05 - 65ms/epoch - 33ms/step
# Epoch 284/1000
# 2/2 - 0s - loss: 21.7994 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-05 - 68ms/epoch - 34ms/step
# Epoch 285/1000
# 2/2 - 0s - loss: 28.7970 - accuracy: 0.5000 - false_negatives_2: 12.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 286/1000
# 2/2 - 0s - loss: 33.0437 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 287/1000
# 2/2 - 0s - loss: 66.2170 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 59ms/epoch - 30ms/step
# Epoch 288/1000
# 2/2 - 0s - loss: 46.6785 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 289/1000
# 2/2 - 0s - loss: 9.5671 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 290/1000
# 2/2 - 0s - loss: 36.4277 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 57ms/epoch - 28ms/step
# Epoch 291/1000
# 2/2 - 0s - loss: 60.5320 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 57ms/epoch - 28ms/step
# Epoch 292/1000
# 2/2 - 0s - loss: 23.0852 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 74ms/epoch - 37ms/step
# Epoch 293/1000
# 2/2 - 0s - loss: 7.1814 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 294/1000
# 2/2 - 0s - loss: 19.8008 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 67ms/epoch - 34ms/step
# Epoch 295/1000
# 2/2 - 0s - loss: 10.3214 - accuracy: 0.3542 - false_negatives_2: 30.0000 - false_positives_2: 1.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 296/1000
# 2/2 - 0s - loss: 13.2390 - accuracy: 0.7083 - false_negatives_2: 2.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 297/1000
# 2/2 - 0s - loss: 10.3786 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 53ms/epoch - 26ms/step
# Epoch 298/1000
# 2/2 - 0s - loss: 67.5911 - accuracy: 0.5000 - false_negatives_2: 12.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 68ms/epoch - 34ms/step
# Epoch 299/1000
# 2/2 - 0s - loss: 8.8973 - accuracy: 0.3750 - false_negatives_2: 23.0000 - false_positives_2: 7.0000 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 300/1000
# 2/2 - 0s - loss: 35.8869 - accuracy: 0.3333 - false_negatives_2: 24.0000 - false_positives_2: 8.0000 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 301/1000
# 2/2 - 0s - loss: 15.5166 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 55ms/epoch - 27ms/step
# Epoch 302/1000
# 2/2 - 0s - loss: 7.7811 - accuracy: 0.3958 - false_negatives_2: 19.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 55ms/epoch - 28ms/step
# Epoch 303/1000
# 2/2 - 0s - loss: 20.8521 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 67ms/epoch - 34ms/step
# Epoch 304/1000
# ...
# Epoch 903/1000
# 2/2 - 0s - loss: 69.8770 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 116ms/epoch - 58ms/step
# Epoch 904/1000
# 2/2 - 0s - loss: 12.0950 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 114ms/epoch - 57ms/step
# Epoch 905/1000
# 2/2 - 0s - loss: 23.8862 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 112ms/epoch - 56ms/step
# Epoch 906/1000
# 2/2 - 0s - loss: 15.4524 - accuracy: 0.5833 - false_negatives_2: 18.0000 - false_positives_2: 2.0000 - lr: 1.0000e-05 - 113ms/epoch - 57ms/step
# Epoch 907/1000
# 2/2 - 0s - loss: 30.4226 - accuracy: 0.5833 - false_negatives_2: 7.0000 - false_positives_2: 13.0000 - lr: 1.0000e-05 - 117ms/epoch - 59ms/step
# Epoch 908/1000
# 2/2 - 0s - loss: 16.5341 - accuracy: 0.4792 - false_negatives_2: 13.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 116ms/epoch - 58ms/step
# Epoch 909/1000
# 2/2 - 0s - loss: 10.0295 - accuracy: 0.5208 - false_negatives_2: 12.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 119ms/epoch - 59ms/step
# Epoch 910/1000
# 2/2 - 0s - loss: 33.2428 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 116ms/epoch - 58ms/step
# Epoch 911/1000
# 2/2 - 0s - loss: 15.9043 - accuracy: 0.6042 - false_negatives_2: 3.0000 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 116ms/epoch - 58ms/step
# Epoch 912/1000
# 2/2 - 0s - loss: 45.9409 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 124ms/epoch - 62ms/step
# Epoch 913/1000
# 2/2 - 0s - loss: 6.5369 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 109ms/epoch - 54ms/step
# Epoch 914/1000
# 2/2 - 0s - loss: 15.8731 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 117ms/epoch - 58ms/step
# Epoch 915/1000
# 2/2 - 0s - loss: 13.8782 - accuracy: 0.7292 - false_negatives_2: 0.0000e+00 - false_positives_2: 13.0000 - lr: 1.0000e-05 - 130ms/epoch - 65ms/step
# Epoch 916/1000
# 2/2 - 0s - loss: 28.6350 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 115ms/epoch - 57ms/step
# Epoch 917/1000
# 2/2 - 0s - loss: 8.8521 - accuracy: 0.5625 - false_negatives_2: 6.0000 - false_positives_2: 15.0000 - lr: 1.0000e-05 - 123ms/epoch - 62ms/step
# Epoch 918/1000
# 2/2 - 0s - loss: 27.9365 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 125ms/epoch - 63ms/step
# Epoch 919/1000
# 2/2 - 0s - loss: 25.6637 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 121ms/epoch - 61ms/step
# Epoch 920/1000
# 2/2 - 0s - loss: 27.0339 - accuracy: 0.3958 - false_negatives_2: 28.0000 - false_positives_2: 1.0000 - lr: 1.0000e-05 - 93ms/epoch - 47ms/step
# Epoch 921/1000
# 2/2 - 0s - loss: 21.1052 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 71ms/epoch - 35ms/step
# Epoch 922/1000
# 2/2 - 0s - loss: 12.4225 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 61ms/epoch - 30ms/step
# Epoch 923/1000
# 2/2 - 0s - loss: 22.4007 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 924/1000
# 2/2 - 0s - loss: 22.0979 - accuracy: 0.5208 - false_negatives_2: 18.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 65ms/epoch - 33ms/step
# Epoch 925/1000
# 2/2 - 0s - loss: 19.1528 - accuracy: 0.7708 - false_negatives_2: 3.0000 - false_positives_2: 8.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 926/1000
# 2/2 - 0s - loss: 56.0074 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 68ms/epoch - 34ms/step
# Epoch 927/1000
# 2/2 - 0s - loss: 7.8605 - accuracy: 0.6458 - false_negatives_2: 1.0000 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 59ms/epoch - 30ms/step
# Epoch 928/1000
# 2/2 - 0s - loss: 9.9368 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 69ms/epoch - 35ms/step
# Epoch 929/1000
# 2/2 - 0s - loss: 10.3537 - accuracy: 0.3542 - false_negatives_2: 30.0000 - false_positives_2: 1.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 930/1000
# 2/2 - 0s - loss: 7.8078 - accuracy: 0.6042 - false_negatives_2: 11.0000 - false_positives_2: 8.0000 - lr: 1.0000e-05 - 63ms/epoch - 32ms/step
# Epoch 931/1000
# 2/2 - 0s - loss: 48.8413 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 932/1000
# 2/2 - 0s - loss: 15.0278 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 61ms/epoch - 31ms/step
# Epoch 933/1000
# 2/2 - 0s - loss: 10.7967 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 934/1000
# 2/2 - 0s - loss: 32.2347 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 70ms/epoch - 35ms/step
# Epoch 935/1000
# 2/2 - 0s - loss: 15.2984 - accuracy: 0.6042 - false_negatives_2: 5.0000 - false_positives_2: 14.0000 - lr: 1.0000e-05 - 71ms/epoch - 36ms/step
# Epoch 936/1000
# 2/2 - 0s - loss: 32.6427 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 937/1000
# 2/2 - 0s - loss: 19.3067 - accuracy: 0.3542 - false_negatives_2: 28.0000 - false_positives_2: 3.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 938/1000
# 2/2 - 0s - loss: 31.4374 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 61ms/epoch - 31ms/step
# Epoch 939/1000
# 2/2 - 0s - loss: 43.2315 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 65ms/epoch - 32ms/step
# Epoch 940/1000
# 2/2 - 0s - loss: 79.7702 - accuracy: 0.5000 - false_negatives_2: 12.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 941/1000
# 2/2 - 0s - loss: 58.8140 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 55ms/epoch - 28ms/step
# Epoch 942/1000
# 2/2 - 0s - loss: 9.6798 - accuracy: 0.3750 - false_negatives_2: 23.0000 - false_positives_2: 7.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 943/1000
# 2/2 - 0s - loss: 61.2507 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 944/1000
# 2/2 - 0s - loss: 10.3734 - accuracy: 0.3333 - false_negatives_2: 22.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 66ms/epoch - 33ms/step
# Epoch 945/1000
# 2/2 - 0s - loss: 31.7204 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 946/1000
# 2/2 - 0s - loss: 9.0816 - accuracy: 0.6667 - false_negatives_2: 15.0000 - false_positives_2: 1.0000 - lr: 1.0000e-05 - 57ms/epoch - 29ms/step
# Epoch 947/1000
# 2/2 - 0s - loss: 10.6293 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-05 - 59ms/epoch - 30ms/step
# Epoch 948/1000
# 2/2 - 0s - loss: 19.6829 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 68ms/epoch - 34ms/step
# Epoch 949/1000
# 2/2 - 0s - loss: 15.8916 - accuracy: 0.3542 - false_negatives_2: 29.0000 - false_positives_2: 2.0000 - lr: 1.0000e-05 - 63ms/epoch - 31ms/step
# Epoch 950/1000
# 2/2 - 0s - loss: 18.3284 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 76ms/epoch - 38ms/step
# Epoch 951/1000
# 2/2 - 0s - loss: 11.0669 - accuracy: 0.6250 - false_negatives_2: 9.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 65ms/epoch - 32ms/step
# Epoch 952/1000
# 2/2 - 0s - loss: 24.3019 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 953/1000
# 2/2 - 0s - loss: 6.1675 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 69ms/epoch - 34ms/step
# Epoch 954/1000
# 2/2 - 0s - loss: 25.6207 - accuracy: 0.7083 - false_negatives_2: 0.0000e+00 - false_positives_2: 14.0000 - lr: 1.0000e-05 - 65ms/epoch - 33ms/step
# Epoch 955/1000
# 2/2 - 0s - loss: 28.0931 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 956/1000
# 2/2 - 0s - loss: 22.3291 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 57ms/epoch - 29ms/step
# Epoch 957/1000
# 2/2 - 0s - loss: 46.1360 - accuracy: 0.4583 - false_negatives_2: 12.0000 - false_positives_2: 14.0000 - lr: 1.0000e-05 - 57ms/epoch - 28ms/step
# Epoch 958/1000
# 2/2 - 0s - loss: 11.5073 - accuracy: 0.7083 - false_negatives_2: 0.0000e+00 - false_positives_2: 14.0000 - lr: 1.0000e-05 - 63ms/epoch - 31ms/step
# Epoch 959/1000
# 2/2 - 0s - loss: 24.9045 - accuracy: 0.4167 - false_negatives_2: 22.0000 - false_positives_2: 6.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 960/1000
# 2/2 - 0s - loss: 28.2941 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 63ms/epoch - 31ms/step
# Epoch 961/1000
# 2/2 - 0s - loss: 8.9137 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 962/1000
# 2/2 - 0s - loss: 21.6452 - accuracy: 0.3958 - false_negatives_2: 29.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 68ms/epoch - 34ms/step
# Epoch 963/1000
# 2/2 - 0s - loss: 10.8643 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 964/1000
# 2/2 - 0s - loss: 72.9561 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 75ms/epoch - 37ms/step
# Epoch 965/1000
# 2/2 - 0s - loss: 69.1859 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 966/1000
# 2/2 - 0s - loss: 8.3055 - accuracy: 0.7083 - false_negatives_2: 0.0000e+00 - false_positives_2: 14.0000 - lr: 1.0000e-05 - 56ms/epoch - 28ms/step
# Epoch 967/1000
# 2/2 - 0s - loss: 9.3485 - accuracy: 0.3125 - false_negatives_2: 28.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 70ms/epoch - 35ms/step
# Epoch 968/1000
# 2/2 - 0s - loss: 19.4675 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 65ms/epoch - 33ms/step
# Epoch 969/1000
# 2/2 - 0s - loss: 16.5418 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 970/1000
# 2/2 - 0s - loss: 27.6109 - accuracy: 0.5417 - false_negatives_2: 11.0000 - false_positives_2: 11.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 971/1000
# 2/2 - 0s - loss: 8.3065 - accuracy: 0.7083 - false_negatives_2: 7.0000 - false_positives_2: 7.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 972/1000
# 2/2 - 0s - loss: 14.8785 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 973/1000
# 2/2 - 0s - loss: 10.2123 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 974/1000
# 2/2 - 0s - loss: 16.3209 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 61ms/epoch - 31ms/step
# Epoch 975/1000
# 2/2 - 0s - loss: 15.8406 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 57ms/epoch - 29ms/step
# Epoch 976/1000
# 2/2 - 0s - loss: 14.9815 - accuracy: 0.5000 - false_negatives_2: 11.0000 - false_positives_2: 13.0000 - lr: 1.0000e-05 - 65ms/epoch - 32ms/step
# Epoch 977/1000
# 2/2 - 0s - loss: 10.2607 - accuracy: 0.4583 - false_negatives_2: 13.0000 - false_positives_2: 13.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 978/1000
# 2/2 - 0s - loss: 46.9792 - accuracy: 0.7083 - false_negatives_2: 2.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 63ms/epoch - 31ms/step
# Epoch 979/1000
# 2/2 - 0s - loss: 25.4433 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 70ms/epoch - 35ms/step
# Epoch 980/1000
# 2/2 - 0s - loss: 15.5706 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 981/1000
# 2/2 - 0s - loss: 29.2326 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 982/1000
# 2/2 - 0s - loss: 7.6825 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 71ms/epoch - 35ms/step
# Epoch 983/1000
# 2/2 - 0s - loss: 16.2726 - accuracy: 0.5833 - false_negatives_2: 10.0000 - false_positives_2: 10.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 984/1000
# 2/2 - 0s - loss: 17.0856 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 61ms/epoch - 30ms/step
# Epoch 985/1000
# 2/2 - 0s - loss: 19.4644 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 61ms/epoch - 31ms/step
# Epoch 986/1000
# 2/2 - 0s - loss: 13.4353 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 55ms/epoch - 28ms/step
# Epoch 987/1000
# 2/2 - 0s - loss: 17.5189 - accuracy: 0.5000 - false_negatives_2: 12.0000 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 65ms/epoch - 33ms/step
# Epoch 988/1000
# 2/2 - 0s - loss: 38.8385 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 989/1000
# 2/2 - 0s - loss: 31.1393 - accuracy: 0.4583 - false_negatives_2: 21.0000 - false_positives_2: 5.0000 - lr: 1.0000e-05 - 58ms/epoch - 29ms/step
# Epoch 990/1000
# 2/2 - 0s - loss: 44.0709 - accuracy: 0.5417 - false_negatives_2: 20.0000 - false_positives_2: 2.0000 - lr: 1.0000e-05 - 60ms/epoch - 30ms/step
# Epoch 991/1000
# 2/2 - 0s - loss: 19.6854 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# Epoch 992/1000
# 2/2 - 0s - loss: 26.6162 - accuracy: 0.5417 - false_negatives_2: 19.0000 - false_positives_2: 3.0000 - lr: 1.0000e-05 - 67ms/epoch - 33ms/step
# Epoch 993/1000
# 2/2 - 0s - loss: 11.1568 - accuracy: 0.5833 - false_negatives_2: 17.0000 - false_positives_2: 3.0000 - lr: 1.0000e-05 - 61ms/epoch - 31ms/step
# Epoch 994/1000
# 2/2 - 0s - loss: 14.2665 - accuracy: 0.6458 - false_negatives_2: 1.0000 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 73ms/epoch - 37ms/step
# Epoch 995/1000
# 2/2 - 0s - loss: 6.7576 - accuracy: 0.6667 - false_negatives_2: 0.0000e+00 - false_positives_2: 16.0000 - lr: 1.0000e-05 - 63ms/epoch - 31ms/step
# Epoch 996/1000
# 2/2 - 0s - loss: 11.4564 - accuracy: 0.6042 - false_negatives_2: 10.0000 - false_positives_2: 9.0000 - lr: 1.0000e-05 - 71ms/epoch - 36ms/step
# Epoch 997/1000
# 2/2 - 0s - loss: 14.0212 - accuracy: 0.7500 - false_negatives_2: 0.0000e+00 - false_positives_2: 12.0000 - lr: 1.0000e-05 - 65ms/epoch - 33ms/step
# Epoch 998/1000
# 2/2 - 0s - loss: 43.7650 - accuracy: 0.4792 - false_negatives_2: 23.0000 - false_positives_2: 2.0000 - lr: 1.0000e-05 - 62ms/epoch - 31ms/step
# Epoch 999/1000
# 2/2 - 0s - loss: 29.4843 - accuracy: 0.3333 - false_negatives_2: 32.0000 - false_positives_2: 0.0000e+00 - lr: 1.0000e-05 - 59ms/epoch - 29ms/step
# Epoch 1000/1000
# 2/2 - 0s - loss: 22.4365 - accuracy: 0.5000 - false_negatives_2: 20.0000 - false_positives_2: 4.0000 - lr: 1.0000e-05 - 64ms/epoch - 32ms/step
# 1/1 [==============================] - 3s 3s/step - loss: 24.7404 - accuracy: 0.7143 - false_negatives_2: 0.0000e+00 - false_positives_2: 6.0000
# Test Loss: 24.7404
# Test Accuracy: 71.43%
# False Negatives: 0
# False Positives: 6
# 1/1 [==============================] - 3s 3s/step
# Confusion Matrix:
# [[ 6  0]
#  [15  0]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of samples for uncertainty estimation
n_samples = 100
predictions = []

# Generate multiple samples from the posterior distribution
for _ in range(n_samples):
    predictions.append(model.predict(x_test))

# Convert predictions to a NumPy array
predictions = np.array(predictions)

# Calculate the predictive mean and standard deviation
mean_prediction = np.mean(predictions, axis=0).flatten()
std_prediction = np.std(predictions, axis=0).flatten()

# Create x-axis values
x_values = np.arange(1, len(mean_prediction) + 1)

# Plot uncertainty using error bars
plt.figure(figsize=(12, 6))
plt.errorbar(x_values, mean_prediction, yerr=2 * std_prediction, fmt='o', label='Predictive Mean')
plt.xlabel('Sample Index')
plt.ylabel('Predicted Value')
plt.xticks(x_values)  # Set the x-axis ticks to the specific numbers
plt.title('Variational Inference Predictive Mean and Uncertainty (2 std)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
